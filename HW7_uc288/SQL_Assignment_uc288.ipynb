# %% [markdown]
# # SQL Assignment - uc288

# %% [markdown]
# Found a Python 2 and 3 compatibility cheat sheet online: http://python-future.org/compatible_idioms.html which I used to update the function by **@fedhere** to be compatible for Python 2 and 3.

# %%
try:
    # Python 3 packages
    from urllib.parse import urlparse, urlencode
    from urllib.request import urlopen, Request
    from urllib.error import HTTPError
except ImportError:
    # Python 2 packages
    from urlparse import urlparse
    from urllib import urlencode
    from urllib2 import urlopen, Request, HTTPError
    
# works for both python 2 and 3
from io import StringIO
import ast
import pandas as pd

# %%
SQL_SOURCE = 'https://uc288.carto.com/api/v2/sql?q='

# %%
def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    # added .encode('utf-8') to prevent errors in python 3
    data = urlencode({'format': format, 'q': query}).encode('utf-8')
    try:
        response = urlopen(source, data)
    # changed syntax to use 'as' keyword
    except HTTPError as e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return pd.read_csv(response)

# %% [markdown]
# ## Task 1: Familiarize with SQL Clauses
# * Sort data by start_station_id, tripduration (only checking trips with duration <= 3 hours
# * Only show the top/last 10 records
# * List all unique start_station_id values
# * Aggregate functions:
#     * Count the number of trips
#     * Find the average / min / max trip duration

# %% [markdown]
# This query combines all the requested information and sorts based on the average trip duration per station.

# %%
sql_1 = '''SELECT DISTINCT start_station_id, 
COUNT(start_station_id) AS trip_counts,
AVG(tripduration) AS avg_tripduration,
MIN(tripduration) AS min_tripduration,
MAX(tripduration) AS max_tripduration
FROM citibike
WHERE tripduration <= 10800
GROUP BY start_station_id
ORDER BY start_station_id ASC, avg_tripduration ASC
LIMIT 10
'''

# %% [markdown]
# This shows the first 10 stations

# %%
queryCartoDB(sql_1)
# Out:
#    start_station_id  trip_counts  avg_tripduration  min_tripduration  \
# 0                72          114        742.701754               107
# 1                79           71        659.140845               149
# 2                82           49        445.346939               138
# 3                83           35        783.685714                73
# 4               116          288        543.965278                66
# 5               119           19       1044.789474               278
# 6               120           17        979.882353               270
# 7               127          209        710.846890                83
# 8               128          247        664.206478                62
# 9               137           96        697.364583                85
#
#    max_tripduration
# 0              2099
# 1              1916
# 2              1581
# 3              2647
# 4              2081
# 5              2167
# 6              2131
# 7              5776
# 8              2875
# 9              2316

# %%
sql_1_2 = '''SELECT DISTINCT start_station_id, 
COUNT(start_station_id) AS trip_counts,
AVG(tripduration) AS avg_tripduration,
MIN(tripduration) AS min_tripduration,
MAX(tripduration) AS max_tripduration
FROM citibike
WHERE tripduration <= 10800
GROUP BY start_station_id
ORDER BY start_station_id DESC, avg_tripduration DESC
LIMIT 10
'''

# %% [markdown]
# This shows the last 10 stations.

# %%
queryCartoDB(sql_1_2)
# Out:
#    start_station_id  trip_counts  avg_tripduration  min_tripduration  \
# 0              3002          184        714.646739                79
# 1              2023           91        771.978022               108
# 2              2022           96        979.062500               107
# 3              2021          141        738.815603                90
# 4              2017           86        763.383721               109
# 5              2012          256        714.519531                79
# 6              2010           76        763.184211               167
# 7              2009          107        777.794393                60
# 8              2008           86        832.220930                94
# 9              2006           79       1130.531646                90
#
#    max_tripduration
# 0              7225
# 1              2454
# 2              2495
# 3              6592
# 4              2476
# 5              2026
# 6              2610
# 7              2765
# 8              3476
# 9              3459

# %%
sql_1_3 = '''SELECT DISTINCT start_station_id, 
COUNT(start_station_id) AS trip_counts,
AVG(tripduration) AS avg_tripduration,
MIN(tripduration) AS min_tripduration,
MAX(tripduration) AS max_tripduration
FROM citibike
WHERE tripduration <= 10800
GROUP BY start_station_id
ORDER BY avg_tripduration DESC
LIMIT 10
'''

# %% [markdown]
# This shows the top 10 stations with the longest trip duration.

# %%
queryCartoDB(sql_1_3)
# Out:
#    start_station_id  trip_counts  avg_tripduration  min_tripduration  \
# 0               471           32       1218.281250                60
# 1               481           13       1143.923077               165
# 2              2006           79       1130.531646                90
# 3              2005            7       1130.285714               545
# 4              2002           45       1116.711111                77
# 5               431           28       1095.535714               184
# 6               372            9       1083.333333               233
# 7               532           50       1076.600000               198
# 8               332           36       1067.111111               201
# 9               119           19       1044.789474               278
#
#    max_tripduration
# 0              2251
# 1              2270
# 2              3459
# 3              2513
# 4              2426
# 5              2423
# 6              2160
# 7              2167
# 8              5930
# 9              2167

# %% [markdown]
# ## Working with date/time
# * Selecting trips started on Feb 2, 2015 only
# * Selecting trips started on the weekends
# * What are the average trip duration during weekends?
# * Can we do the sam efor weekday?

# %% [markdown]
# ### Trips started on Feb. 2, 2015 only

# %%
sql_2_1 = '''SELECT starttime, stoptime, start_station_id, 
end_station_id, tripduration, usertype, gender, birth_year
FROM citibike
WHERE starttime >= '2015-02-02 00:00:00'
AND starttime < '2015-02-03 00:00:00'
ORDER BY starttime
'''

# %%
queryCartoDB(sql_2_1)
# Out:
#                    starttime                stoptime  start_station_id  \
# 0     2015-02-02 00:02:00+00  2015-02-02 00:05:00+00               442
# 1     2015-02-02 00:03:00+00  2015-02-02 00:10:00+00               326
# 2     2015-02-02 00:04:00+00  2015-02-02 00:09:00+00               279
# 3     2015-02-02 00:06:00+00  2015-02-02 00:13:00+00               496
# 4     2015-02-02 00:07:00+00  2015-02-02 00:12:00+00               477
# 5     2015-02-02 00:08:00+00  2015-02-02 00:18:00+00               467
# 6     2015-02-02 00:09:00+00  2015-02-02 00:15:00+00               434
# 7     2015-02-02 00:11:00+00  2015-02-02 00:19:00+00               330
# 8     2015-02-02 00:12:00+00  2015-02-02 00:25:00+00               521
# 9     2015-02-02 00:12:00+00  2015-02-02 00:22:00+00               504
# 10    2015-02-02 00:12:00+00  2015-02-02 00:18:00+00               285
# 11    2015-02-02 00:13:00+00  2015-02-02 00:25:00+00               301
# 12    2015-02-02 00:13:00+00  2015-02-02 00:16:00+00               279
# 13    2015-02-02 00:13:00+00  2015-02-02 00:16:00+00               342
# 14    2015-02-02 00:14:00+00  2015-02-02 00:21:00+00               470
# 1458             302           733  Subscriber       2      1976.0
#
# [1459 rows x 8 columns]

# %% [markdown]
# ### Trips that started on the weekends with the average duration

# %%
sql_2_2 = '''SELECT date_part('dow', starttime) as day_of_week,
AVG(tripduration) as avg_tripduration
FROM citibike
WHERE date_part('dow', starttime) IN (0, 6)
GROUP BY date_part('dow', starttime)'''

# %%
queryCartoDB(sql_2_2)
# Out:
#    day_of_week  avg_tripduration
# 0            0        638.149200
# 1            6        686.460825

# %%
sql_2_21 = '''SELECT AVG(tripduration) as avg_tripduration
FROM citibike
WHERE date_part('dow', starttime) IN (0, 6)'''

# %% [markdown]
# The average trip duration for the weekend.

# %%
queryCartoDB(sql_2_21)
# Out:
#    avg_tripduration  Unnamed: 1
# 0        662.942181         NaN

# %% [markdown]
# ### Trips that started on the weekdays with the average duration

# %%
sql_2_3 = '''SELECT date_part('dow', starttime) as day_of_week,
AVG(tripduration) as avg_tripduration
FROM citibike
WHERE date_part('dow', starttime) > 0
AND  date_part('dow', starttime) < 6
GROUP BY date_part('dow', starttime)
ORDER BY day_of_week'''

# %%
queryCartoDB(sql_2_3)
# Out:
#    day_of_week  avg_tripduration
# 0            1        920.862234
# 1            2        767.224443
# 2            3        697.556559
# 3            4        623.396720
# 4            5        637.116968

# %%
sql_2_31 = '''SELECT AVG(tripduration) as avg_tripduration
FROM citibike
WHERE date_part('dow', starttime) > 0
AND  date_part('dow', starttime) < 6'''

# %% [markdown]
# The average trip duration for the weekdays.

# %%
queryCartoDB(sql_2_31)
# Out:
#    avg_tripduration  Unnamed: 1
# 0        681.052292         NaN

# %% [markdown]
# ## Task 3 - Working with Space

# %% [markdown]
# * Showing the list of start station locations
#     * Using GROUP BY
# * Showing the number of trips started per station
#     * … but only for stations within 500m of Time Square!
#     * The coordinates of Time Square is (40.7577,-73.9857)

# %%
sql_3 = '''SELECT start_station_latitude, start_station_longitude, start_station_name,
    CDB_TransformToWebmercator(CDB_LatLng(start_station_latitude, start_station_longitude)) AS the_geom_webmercator,
    MIN(cartodb_id) AS cartodb_id,
    COUNT(tripduration) AS numTrips
FROM citibike
WHERE ST_DWithin(CDB_LatLng(start_station_latitude, start_station_longitude)::geography, 
                 CDB_LatLng(40.7577,-73.9857)::geography,
                500)
GROUP BY start_station_latitude, start_station_longitude, start_station_name
ORDER BY numtrips'''

# %%
queryCartoDB(sql_3)
# Out:
#    start_station_latitude  start_station_longitude  start_station_name  \
# 0               40.755273               -73.983169     W 43 St & 6 Ave
# 1               40.756800               -73.982912     W 45 St & 6 Ave
# 2               40.759291               -73.988597     W 45 St & 8 Ave
# 3               40.760647               -73.984427  Broadway & W 49 St
# 4               40.757570               -73.990985     W 42 St & 8 Ave
# 5               40.755136               -73.986580  Broadway & W 41 St
# 6               40.756405               -73.990026     W 41 St & 8 Ave
#
#                                 the_geom_webmercator  cartodb_id  numtrips
# 0  0101000020110F0000F22A632FBE6A5FC1363A28CFADFB...        1115       112
# 1  0101000020110F00009BB87D02B76A5FC146C144E9E5FB...          19       141
# 2  0101000020110F00001607D538556B5FC119A6CA6F41FC...         124       141
# 3  0101000020110F000020D6742CE16A5FC112F4D73D73FC...          42       213
# 4  0101000020110F00003F9300B2976B5FC1B8B88F3102FC...         783       221
# 5  0101000020110F000004AF971C1D6B5FC17A48F3C1A8FB...          54       251
# 6  0101000020110F0000F55695027D6B5FC186E5BB69D7FB...          33       507

# %% [markdown]
# ## Task 4 - Putting it all together

# %% [markdown]
# ### Find the station that had the longest average trip duration during weekends and within 500m of TimeSquare!

# %%
sql_4_1 = '''SELECT start_station_latitude, start_station_longitude, start_station_name,
    CDB_TransformToWebmercator(CDB_LatLng(start_station_latitude, start_station_longitude)) AS the_geom_webmercator,
    MIN(cartodb_id) AS cartodb_id,
    AVG(tripduration) AS avg_duration
FROM citibike
WHERE ST_DWithin(CDB_LatLng(start_station_latitude, start_station_longitude)::geography, 
                 CDB_LatLng(40.7577,-73.9857)::geography,
                500)
AND date_part('dow', starttime) IN (0, 6)
GROUP BY start_station_latitude, start_station_longitude, start_station_name
ORDER BY avg_duration DESC'''

# %%
queryCartoDB(sql_4_1)
# Out:
#    start_station_latitude  start_station_longitude  start_station_name  \
# 0               40.760647               -73.984427  Broadway & W 49 St
# 1               40.759291               -73.988597     W 45 St & 8 Ave
# 2               40.755136               -73.986580  Broadway & W 41 St
# 3               40.756800               -73.982912     W 45 St & 6 Ave
# 4               40.756405               -73.990026     W 41 St & 8 Ave
# 5               40.755273               -73.983169     W 43 St & 6 Ave
# 6               40.757570               -73.990985     W 42 St & 8 Ave
#
#                                 the_geom_webmercator  cartodb_id  avg_duration
# 0  0101000020110F000020D6742CE16A5FC112F4D73D73FC...          42   1010.104167
# 1  0101000020110F00001607D538556B5FC119A6CA6F41FC...         124    762.931818
# 2  0101000020110F000004AF971C1D6B5FC17A48F3C1A8FB...          54    683.121212
# 3  0101000020110F00009BB87D02B76A5FC146C144E9E5FB...          19    675.400000
# 4  0101000020110F0000F55695027D6B5FC186E5BB69D7FB...          33    643.260274
# 5  0101000020110F0000F22A632FBE6A5FC1363A28CFADFB...        1115    629.700000
# 6  0101000020110F00003F9300B2976B5FC1B8B88F3102FC...         783    579.142857

# %%
sql_4_11 = '''SELECT start_station_latitude, start_station_longitude, start_station_name,
    CDB_TransformToWebmercator(CDB_LatLng(start_station_latitude, start_station_longitude)) AS the_geom_webmercator,
    date_part('dow', starttime) AS day_of_week, 
    MIN(cartodb_id) AS cartodb_id,
    AVG(tripduration) AS avg_duration
FROM citibike
WHERE ST_DWithin(CDB_LatLng(start_station_latitude, start_station_longitude)::geography, 
                 CDB_LatLng(40.7577,-73.9857)::geography,
                500)
AND date_part('dow', starttime) IN (0, 6)
GROUP BY start_station_latitude, start_station_longitude, start_station_name, date_part('dow', starttime) 
ORDER BY day_of_week, avg_duration DESC'''

# %%
queryCartoDB(sql_4_11)
# Out:
#     start_station_latitude  start_station_longitude  start_station_name  \
# 0                40.759291               -73.988597     W 45 St & 8 Ave
# 1                40.755136               -73.986580  Broadway & W 41 St
# 2                40.756405               -73.990026     W 41 St & 8 Ave
# 3                40.760647               -73.984427  Broadway & W 49 St
# 4                40.756800               -73.982912     W 45 St & 6 Ave
# 5                40.757570               -73.990985     W 42 St & 8 Ave
# 6                40.755273               -73.983169     W 43 St & 6 Ave
# 7                40.760647               -73.984427  Broadway & W 49 St
# 8                40.756800               -73.982912     W 45 St & 6 Ave
# 9                40.755273               -73.983169     W 43 St & 6 Ave
# 10               40.759291               -73.988597     W 45 St & 8 Ave
# 11               40.755136               -73.986580  Broadway & W 41 St
# 12               40.756405               -73.990026     W 41 St & 8 Ave
# 13               40.757570               -73.990985     W 42 St & 8 Ave
#
#                                  the_geom_webmercator  day_of_week  \
# 0   0101000020110F00001607D538556B5FC119A6CA6F41FC...            0
# 1   0101000020110F000004AF971C1D6B5FC17A48F3C1A8FB...            0
# 2   0101000020110F0000F55695027D6B5FC186E5BB69D7FB...            0
# 3   0101000020110F000020D6742CE16A5FC112F4D73D73FC...            0
# 4   0101000020110F00009BB87D02B76A5FC146C144E9E5FB...            0
# 5   0101000020110F00003F9300B2976B5FC1B8B88F3102FC...            0
# 6   0101000020110F0000F22A632FBE6A5FC1363A28CFADFB...            0
# 7   0101000020110F000020D6742CE16A5FC112F4D73D73FC...            6
# 8   0101000020110F00009BB87D02B76A5FC146C144E9E5FB...            6
# 9   0101000020110F0000F22A632FBE6A5FC1363A28CFADFB...            6
# 10  0101000020110F00001607D538556B5FC119A6CA6F41FC...            6
# 11  0101000020110F000004AF971C1D6B5FC17A48F3C1A8FB...            6
# 12  0101000020110F0000F55695027D6B5FC186E5BB69D7FB...            6
# 13  0101000020110F00003F9300B2976B5FC1B8B88F3102FC...            6
#
#     cartodb_id  avg_duration
# 0          124    799.722222
# 1           54    671.818182
# 2           33    647.483871
# 3           42    594.954545
# 4           19    555.000000
# 5          783    476.800000
# 6         1115    410.500000
# 7        39625   1361.384615
# 8        41260    813.000000
# 9        40490    775.833333
# 10       39443    737.461538
# 11       39430    688.772727
# 12       39470    640.142857
# 13       39781    636.000000

# %% [markdown]
# ### Extra:
# **Create lines** for trips started from stations within 500m of Times Square and **lasted less than 2 hours**. The number of trips per each pair of stations are output as attributes of these lines.

# %%
sql_4_2 = '''SELECT start_station_latitude, start_station_longitude, start_station_name,
    end_station_latitude, end_station_longitude, end_station_name,
    ST_Makeline(CDB_TransformToWebmercator(CDB_LatLng(start_station_latitude, start_station_longitude)),
                   CDB_TransformToWebmercator(CDB_LatLng(end_station_latitude, end_station_longitude))) AS the_geom_webmercator,
    MIN(cartodb_id) AS cartodb_id,
    COUNT(tripduration) AS numTrips
FROM citibike
WHERE ST_DWithin(CDB_LatLng(start_station_latitude, start_station_longitude)::geography, 
                 CDB_LatLng(40.7577,-73.9857)::geography,
                500)
    AND tripduration < 7200
GROUP BY start_station_latitude, start_station_longitude, start_station_name, end_station_latitude, end_station_longitude, end_station_name'''

# %%
queryCartoDB(sql_4_2)
# Out:
#      start_station_latitude  start_station_longitude  start_station_name  \
# 0                 40.756405               -73.990026     W 41 St & 8 Ave
# 1                 40.757570               -73.990985     W 42 St & 8 Ave
# 2                 40.755136               -73.986580  Broadway & W 41 St
# 3                 40.755136               -73.986580  Broadway & W 41 St
# 4                 40.755273               -73.983169     W 43 St & 6 Ave
# 5                 40.755136               -73.986580  Broadway & W 41 St
# 6                 40.756405               -73.990026     W 41 St & 8 Ave
# 7                 40.755273               -73.983169     W 43 St & 6 Ave
# 8                 40.756405               -73.990026     W 41 St & 8 Ave
# 9                 40.757570               -73.990985     W 42 St & 8 Ave
# 10                40.757570               -73.990985     W 42 St & 8 Ave
# 11                40.756800               -73.982912     W 45 St & 6 Ave
# 12                40.760647               -73.984427  Broadway & W 49 St
# 13                40.755136               -73.986580  Broadway & W 41 St
# 14                40.755136               -73.986580  Broadway & W 41 St
# 15                40.755136               -73.986580  Broadway & W 41 St
# 16                40.757570               -73.990985     W 42 St & 8 Ave
# 17                40.755136               -73.986580  Broadway & W 41 St
# 18                40.755136               -73.986580  Broadway & W 41 St
# 19                40.757570               -73.990985     W 42 St & 8 Ave
# 20                40.759291               -73.988597     W 45 St & 8 Ave
# 21                40.755273               -73.983169     W 43 St & 6 Ave
# 22                40.755136               -73.986580  Broadway & W 41 St
# 23                40.757570               -73.990985     W 42 St & 8 Ave
# 24                40.756800               -73.982912     W 45 St & 6 Ave
# 25                40.756405               -73.990026     W 41 St & 8 Ave
# 26                40.756405               -73.990026     W 41 St & 8 Ave
# 27                40.756405               -73.990026     W 41 St & 8 Ave
# 28                40.756405               -73.990026     W 41 St & 8 Ave
# 29                40.756405               -73.990026     W 41 St & 8 Ave
# ..                      ...                      ...                 ...
# 542               40.756800               -73.982912     W 45 St & 6 Ave
# 543               40.757570               -73.990985     W 42 St & 8 Ave
# 544               40.755136               -73.986580  Broadway & W 41 St
# 545               40.760647               -73.984427  Broadway & W 49 St
# 546               40.757570               -73.990985     W 42 St & 8 Ave
# 547               40.757570               -73.990985     W 42 St & 8 Ave
# 548               40.755273               -73.983169     W 43 St & 6 Ave
# 549               40.755273               -73.983169     W 43 St & 6 Ave
# 550               40.757570               -73.990985     W 42 St & 8 Ave
# 551               40.755136               -73.986580  Broadway & W 41 St
# 552               40.756405               -73.990026     W 41 St & 8 Ave
# 553               40.755136               -73.986580  Broadway & W 41 St
# 554               40.755273               -73.983169     W 43 St & 6 Ave
# 555               40.755136               -73.986580  Broadway & W 41 St
# 556               40.759291               -73.988597     W 45 St & 8 Ave
# 557               40.755136               -73.986580  Broadway & W 41 St
# 558               40.757570               -73.990985     W 42 St & 8 Ave
# 559               40.759291               -73.988597     W 45 St & 8 Ave
# 560               40.755273               -73.983169     W 43 St & 6 Ave
# 561               40.755136               -73.986580  Broadway & W 41 St
# 562               40.759291               -73.988597     W 45 St & 8 Ave
# 563               40.756800               -73.982912     W 45 St & 6 Ave
# 564               40.760647               -73.984427  Broadway & W 49 St
# 565               40.759291               -73.988597     W 45 St & 8 Ave
# 566               40.756800               -73.982912     W 45 St & 6 Ave
# 567               40.755136               -73.986580  Broadway & W 41 St
# 568               40.755136               -73.986580  Broadway & W 41 St
# 569               40.756405               -73.990026     W 41 St & 8 Ave
# 570               40.755136               -73.986580  Broadway & W 41 St
# 571               40.755273               -73.983169     W 43 St & 6 Ave
#
#      end_station_latitude  end_station_longitude  \
# 0               40.704718             -74.009260
# 1               40.760958             -73.967245
# 2               40.739713             -73.994564
# 3               40.735243             -73.987586
# 4               40.769155             -73.981918
# 5               40.720196             -73.989978
# 6               40.758281             -73.970694
# 7               40.751551             -73.993934
# 8               40.760660             -73.980420
# 9               40.750977             -73.987654
# 10              40.695977             -73.990149
# 11              40.764397             -73.973715
# 12              40.745497             -74.001971
# 13              40.763406             -73.977225
# 14              40.761628             -73.972924
# 15              40.756458             -73.993722
# 16              40.759345             -73.967597
# 17              40.760193             -73.991255
# 18              40.728419             -73.987140
# 19              40.762288             -73.983362
# 20              40.766953             -73.981693
# 21              40.744449             -73.983035
# 22              40.750020             -73.969053
# 23              40.770513             -73.988038
# 24              40.763707             -73.985162
# 25              40.756014             -73.967416
# 26              40.737262             -73.992390
# 27              40.759711             -73.974023
# 28              40.748901             -73.976049
# 29              40.740259             -73.984092
# ..                    ...                    ...
# 542             40.742354             -73.989151
# 543             40.750200             -73.990931
# 544             40.762272             -73.987882
# 545             40.740259             -73.984092
# 546             40.728145             -73.990214
# 547             40.734546             -73.990741
# 548             40.748549             -73.988084
# 549             40.734546             -73.990741
# 550             40.748549             -73.988084
# 551             40.756405             -73.990026
# 552             40.745497             -74.001971
# 553             40.750664             -74.001768
# 554             40.752062             -73.981632
# 555             40.759923             -73.976485
# 556             40.760094             -73.994618
# 557             40.744023             -73.976056
# 558             40.747348             -73.997236
# 559             40.756660             -73.976684
# 560             40.750200             -73.990931
# 561             40.727791             -73.985649
# 562             40.753231             -73.970325
# 563             40.743943             -73.979661
# 564             40.765909             -73.976342
# 565             40.771522             -73.990541
# 566             40.765265             -73.981923
# 567             40.746745             -74.007756
# 568             40.726218             -73.983799
# 569             40.738274             -73.987520
# 570             40.740343             -73.989551
# 571             40.760647             -73.984427
#
#                       end_station_name  \
# 0            Pearl St & Hanover Square
# 1                      E 58 St & 3 Ave
# 2                      W 18 St & 6 Ave
# 3                  E 16 St & Irving Pl
# 4                   Broadway & W 60 St
# 5              Allen St & Rivington St
# 6              E 53 St & Lexington Ave
# 7                      8 Ave & W 33 St
# 8                      W 51 St & 6 Ave
# 9                   Broadway & W 36 St
# 10         Cadman Plaza E & Tillary St
# 11   Grand Army Plaza & Central Park S
# 12                     9 Ave & W 22 St
# 13                     W 56 St & 6 Ave
# 14               E 56 St & Madison Ave
# 15                     W 39 St & 9 Ave
# 16                     E 56 St & 3 Ave
# 17                     9 Ave & W 45 St
# 18                 St Marks Pl & 2 Ave
# 19                  Broadway & W 51 St
# 20                  Broadway & W 58 St
# 21                E 30 St & Park Ave S
# 22                     1 Ave & E 44 St
# 23                    W 59 St & 10 Ave
# 24                     8 Ave & W 52 St
# 25                     E 52 St & 2 Ave
# 26                     E 16 St & 5 Ave
# 27               E 53 St & Madison Ave
# 28                     E 39 St & 3 Ave
# 29             Lexington Ave & E 24 St
# ..                                 ...
# 542                 Broadway & W 24 St
# 543                    W 33 St & 7 Ave
# 544                    W 49 St & 8 Ave
# 545            Lexington Ave & E 24 St
# 546             Shevchenko Pl & E 7 St
# 547                 Broadway & E 14 St
# 548                 Broadway & W 32 St
# 549                 Broadway & E 14 St
# 550                 Broadway & W 32 St
# 551                    W 41 St & 8 Ave
# 552                    9 Ave & W 22 St
# 553                   10 Ave & W 28 St
# 554                    E 40 St & 5 Ave
# 555                    W 52 St & 5 Ave
# 556                   W 43 St & 10 Ave
# 557                    E 33 St & 2 Ave
# 558                    W 26 St & 8 Ave
# 559              E 48 St & Madison Ave
# 560                    W 33 St & 7 Ave
# 561                St Marks Pl & 1 Ave
# 562                    E 47 St & 2 Ave
# 563                    E 31 St & 3 Ave
# 564             Central Park S & 6 Ave
# 565                   11 Ave & W 59 St
# 566                 Broadway & W 55 St
# 567                   W 20 St & 11 Ave
# 568                  E 7 St & Avenue A
# 569                 E 20 St & Park Ave
# 570                 Broadway & E 22 St
# 571                 Broadway & W 49 St
#
#                                   the_geom_webmercator  cartodb_id  numtrips
# 0    0102000020110F000002000000F55695027D6B5FC186E5...       13694         3
# 1    0102000020110F0000020000003F9300B2976B5FC1B8B8...       12816        10
# 2    0102000020110F00000200000004AF971C1D6B5FC17A48...       21914         1
# 3    0102000020110F00000200000004AF971C1D6B5FC17A48...       22653         1
# 4    0102000020110F000002000000F22A632FBE6A5FC1363A...       20088         6
# 5    0102000020110F00000200000004AF971C1D6B5FC17A48...        3976         1
# 6    0102000020110F000002000000F55695027D6B5FC186E5...       15127         4
# 7    0102000020110F000002000000F22A632FBE6A5FC1363A...       36993         1
# 8    0102000020110F000002000000F55695027D6B5FC186E5...       14514         8
# 9    0102000020110F0000020000003F9300B2976B5FC1B8B8...       15100         1
# 10   0102000020110F0000020000003F9300B2976B5FC1B8B8...        8505         1
# 11   0102000020110F0000020000009BB87D02B76A5FC146C1...       13474         3
# 12   0102000020110F00000200000020D6742CE16A5FC112F4...       19572         1
# 13   0102000020110F00000200000004AF971C1D6B5FC17A48...        8722         4
# 14   0102000020110F00000200000004AF971C1D6B5FC17A48...       11094         2
# 15   0102000020110F00000200000004AF971C1D6B5FC17A48...       25560         2
# 16   0102000020110F0000020000003F9300B2976B5FC1B8B8...       23971         1
# 17   0102000020110F00000200000004AF971C1D6B5FC17A48...       15951         1
# 18   0102000020110F00000200000004AF971C1D6B5FC17A48...       37805         1
